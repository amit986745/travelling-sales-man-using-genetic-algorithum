# %% [markdown]
# # travelling sale man problem using GA

# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
from itertools import permutations as perm
import math
import copy

# %%
dataset= pd.read_csv('tsp48.csv')
dataset.head()
# Out:
#    city1  city2  city3  city4  city5  city6  city7  city8  city9  city10  ...  \
# 0      0   4727   1205   6363   3657   3130   2414    563    463    5654  ...
# 1   4727      0   3588   2012   1842   6977   6501   5187   5028    2327  ...
# 2   1205   3588      0   5163   2458   3678   3071   1742   1444    4462  ...
# 3   6363   2012   5163      0   2799   8064   7727   6878   6581    1402  ...
# 4   3657   1842   2458   2799      0   5330   4946   4200   3824    2012  ...
#
#    city39  city40  city41  city42  city43  city44  city45  city46  city47  \
# 0    3530     825    2188    4820    3489    1947    6835    1542    2379
# 1    3085    4564    2756    1591    7027    6186    3472    5461    4390
# 2    2482    1027    1395    3617    3891    2686    5661    2023    1867
# 3    3669    6011    4638    1681    7987    7502    1877    6758    5360
# 4    1252    3227    2426    1169    5313    4706    3241    3962    2651
#
#    city48
# 0    3744
# 1    2088
# 2    2560
# 3    2844
# 4     304
#
# [5 rows x 48 columns]

# %%
X=dataset.iloc[:, :].values
m=10
alpha=0

print(X)
# Out:
# [[   0 4727 1205 ... 1542 2379 3744]
#  [4727    0 3588 ... 5461 4390 2088]
#  [1205 3588    0 ... 2023 1867 2560]
#  ...
#  [1542 5461 2023 ...    0 1644 3928]
#  [2379 4390 1867 ... 1644    0 2532]
#  [3744 2088 2560 ... 3928 2532    0]]

# %%
s0=[]  #solution set intialization
s_best=[]
for i in range(m):
    
        index_city=np.arange(1,48)
        np.random.shuffle(index_city)
        
        s0.append(list(index_city))

# %%
iteration=0
while(iteration<3000):
    cost=[] #creaing empty list of cost 
    i=0
    for i in range(m):

        z=[0]+s0[i]+[0]

        c=0
        j=0
        for j in range(len(z)-1):

            c=c+X[z[j]][z[j+1]]
        cost.append(c)
     
    cost=np.array(np.max(cost)-np.array(cost))  #coverting maximum to minimum 
    
    p=[]
    i=0
    if np.sum(cost)==0:
        break;
        
        
    for i in range(m):  #FITNESS 
        x=round(cost[i]/(np.sum(cost)),4)
        p.append(x)
        
    ck=[]
    i=0
   
            
         
    for i in range(m):
        k=round(p[i]*20)
        ck.append(k)
        
    s1=np.array(s0)
        
        
    cs=[]
    i=0
    for i in range(m):  #COST OF CHILDRENS
        x=int(ck[i])
        j=0
        for j in range(x):
            a=np.random.randint(47)
            b=np.random.randint(47)
            temp =s1[i][a]
            s1[i][a]=s1[i][b]
            s1[i][b]=temp
            css=copy.deepcopy(s1[i])
            css=list(css)
            cs.append(css)
        cs.append(s0[i])
            
            
    
    total_cost=[] #creaing empty list of total cost
    l=len(cs)
    solution_set=[]
    i=0
    for i in range(l):

        z=[0]+cs[i]+[0]


        c=0
        j=0
        for j in range(len(z)-1):

            c=c+X[z[j]][z[j+1]]

        total_cost.append(c)

        solution_set.append([c,cs[i]])
    
    a=sorted(solution_set,key=lambda l:l[0])
    
    S1=[]
    s_best.append(a[0][1])
    
    i=0
    if iteration==1000 or iteration==2000:
        alpha=m-1
   
    for i in range(m-alpha):
        S1.append(a[i][1])

    for i in range(alpha):
    
        index_city=np.arange(1,48)
        np.random.shuffle(index_city)
        
        S1.append(list(index_city))
    
    s0=S1   
    iteration+=1

# %%
# BEST SOLUTION VISUALATIZATION
bestcost_list=[] 
bestcost=[]
for i in range(len(s_best)):

    z=[0]+s_best[i]+[0]

    c=0
    for j in range(len(z)-1):

        c=c+X[z[j]][z[j+1]]

    bestcost_list.append(c)

print(s0[0])

z=[0]+s0[0]+[0]

c=0
for j in range(len(z)-1):

    c=c+X[z[j]][z[j+1]]

bestcost.append(c)
print(bestcost)
# Out:
# [7, 37, 30, 43, 27, 5, 36, 18, 26, 16, 42, 29, 19, 20, 31, 23, 9, 44, 34, 3, 25, 41, 1, 28, 33, 4, 47, 38, 24, 13, 12, 46, 35, 6, 17, 10, 22, 2, 39, 11, 32, 45, 14, 8, 21, 15, 40]
# [42827]

# %%
# print(bestcost_list)
plt.plot(bestcost_list)

# %%
cityset= pd.read_csv('citytsp.csv')
xy=cityset.loc[:, :].values
cityindex=[0]+s0[0]+[0]
print(len(cityindex))
print(cityindex)
print(len(xy))
# Out:
# 49
# [0, 7, 37, 30, 43, 27, 5, 36, 18, 26, 16, 42, 29, 19, 20, 31, 23, 9, 44, 34, 3, 25, 41, 1, 28, 33, 4, 47, 38, 24, 13, 12, 46, 35, 6, 17, 10, 22, 2, 39, 11, 32, 45, 14, 8, 21, 15, 40, 0]
# 48

# %%
X1=[]
Y1=[]
for i in range(49):
    x=xy[cityindex[i]][0]
    y=xy[cityindex[i]][1]
    X1.append(x)
    Y1.append(y)
    
                       
X1=np.array(X1)
Y1=np.array(Y1)

# %%
plt.figure(figsize=(20,15))
plt.plot(X1,Y1)

for i, txt in enumerate(cityindex):
    plt.annotate(txt, (X1[i], Y1[i]))
